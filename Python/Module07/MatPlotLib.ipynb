# %% [markdown]
# ## MATPLOT LIBRARY

# %% [markdown]
# ### Why do we need visualize data?
# Visualization of data give us more understanding of data.

# %% [markdown]
# Python offers multiple libaray to visualize data but generally we use matplotlib, seaborn and plotly, bokeh

# %% [markdown]
# ## ***MatplotLib***
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# To avoid warnings 
import warnings
warnings.filterwarnings('ignore') # supress all the warning

# %%
# Line, Scatter, Bar, Histogram, pie chart, box plot, violin plot

# %%
# Generate random numbers from numpy
x = np.random.rand(50)
x
# Out:
# array([0.79999187, 0.90069277, 0.70429906, 0.01993966, 0.21578151,
#        0.34463841, 0.84757015, 0.35758113, 0.51021321, 0.78643851,
#        0.32332904, 0.87379853, 0.70792979, 0.01135086, 0.05881979,
#        0.00196867, 0.62360347, 0.30695454, 0.91945579, 0.32866316,
#        0.41629106, 0.32004188, 0.5837538 , 0.45626089, 0.94971589,
#        0.82045572, 0.13097466, 0.50148874, 0.40209878, 0.02201915,
#        0.99960006, 0.4019836 , 0.16331007, 0.96249738, 0.26493188,
#        0.74009497, 0.17546225, 0.05994371, 0.50779937, 0.36690695,
#        0.53439753, 0.11790319, 0.02661729, 0.70143363, 0.54900971,
#        0.19694826, 0.2756758 , 0.48484687, 0.911559  , 0.60039497])

# %%
len(x)
# Out:
# 50

# %%
np.random.randn(50)
# Out:
# array([-0.87699467, -1.27471924, -1.48334688, -1.1567371 , -0.50163686,
#         0.19887089,  0.35827443,  1.14649282, -1.13542612,  0.12602923,
#         0.58627754,  0.48488825,  0.78753979,  0.59378034, -0.86092301,
#         0.74990506,  0.60105012,  1.39268965,  1.60372417, -0.39982178,
#        -0.27799903, -0.4554665 , -0.39497071,  1.09108015, -0.00767075,
#        -1.16819208, -1.428628  , -1.87565325,  0.41336794,  0.38276384,
#        -0.3608669 , -0.04650792,  0.79848326,  0.27935034,  1.56749523,
#        -0.13749243, -1.24738096,  0.20339053, -0.95000489, -1.0960507 ,
#        -0.0652723 , -1.26239925, -0.38577986, -0.16415052,  1.37178993,
#        -0.64228036,  0.47764178,  0.08792462, -1.25780941,  0.47094381])

# %%
df = pd.DataFrame(np.random.randn(1000), columns=['Data'], index=pd.date_range(start='2024-02-20', periods=1000))
df
# Out:
#                 Data
# 2024-02-20  0.320109
# 2024-02-21  0.442434
# 2024-02-22 -0.445598
# 2024-02-23  1.328398
# 2024-02-24  0.050577
# ...              ...
# 2026-11-11  0.122000
# 2026-11-12  1.030088
# 2026-11-13 -1.508059
# 2026-11-14 -2.059228
# 2026-11-15  1.837000
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize=(20, 8))

# Summary >> Most values are fluctuating between 3 to -3 (Beautiful way of visualization)
# Out:
# <Axes: >

# %%
x
# Out:
# array([0.79999187, 0.90069277, 0.70429906, 0.01993966, 0.21578151,
#        0.34463841, 0.84757015, 0.35758113, 0.51021321, 0.78643851,
#        0.32332904, 0.87379853, 0.70792979, 0.01135086, 0.05881979,
#        0.00196867, 0.62360347, 0.30695454, 0.91945579, 0.32866316,
#        0.41629106, 0.32004188, 0.5837538 , 0.45626089, 0.94971589,
#        0.82045572, 0.13097466, 0.50148874, 0.40209878, 0.02201915,
#        0.99960006, 0.4019836 , 0.16331007, 0.96249738, 0.26493188,
#        0.74009497, 0.17546225, 0.05994371, 0.50779937, 0.36690695,
#        0.53439753, 0.11790319, 0.02661729, 0.70143363, 0.54900971,
#        0.19694826, 0.2756758 , 0.48484687, 0.911559  , 0.60039497])

# %%
x = np.random.rand(50)
y = np.random.rand(50)

# %% [markdown]
# ## Scatter Plot
# A **scatter plot** is used to visualize the relationship between two numerical variables by plotting data points on a 2D graph. It helps identify patterns, correlations (positive, negative, or none), and trends between variables. For example, in analyzing sales vs. advertising spend, a scatter plot can reveal whether increased spending leads to higher sales. It is also useful for detecting outliers, where certain points deviate significantly from the trend. Scatter plots are widely used in data analysis, statistics, and machine learning to understand dependencies and make predictions based on observed data distributions.

# %%
plt.scatter(x, y)

# %% [markdown]
# ## Line Plot
# A **line plot** is used to show trends or changes over time by connecting data points with a continuous line. It is ideal for visualizing time series data, such as stock prices, temperature changes, or website traffic over days, months, or years. Unlike scatter plots, which show individual data points, line plots emphasize the overall trend, making it easier to identify patterns like upward or downward movement, seasonal fluctuations, or cyclic behavior. They are widely used in financial analysis, forecasting, and scientific research where tracking progression over time is essential.
# </br>
# </br>
# Mostly in x axis the date-timecolumn is there

# %%
x = [1, 2, 3, 4, 5] # Assume x is number of days
y = [9, 7, 3, 8, 5] # Y is price of stocks

plt.plot(x, y)

# %% [markdown]
# ### Adding details into plots

# %%
plt.plot(x, y, color="red", marker="*")
plt.title("Line chart to understand the syntax")
plt.xlabel("Day interval as x points")
plt.ylabel("Stocks priceas y points")
plt.show()

# %%
plt.plot(x, y, color="green", marker = 'o', linestyle = "--")
plt.title("Line chart to understand the syntax")
plt.xlabel("Day interval as x points")
plt.ylabel("Stocks priceas y points")
plt.show()

# %%
# Can we make line more thicker?
plt.plot(x, y, color = "blue", marker='o', linestyle="--", linewidth='5')
plt.title("Line chart to understand the syntax")
plt.xlabel("Day interval as x points")
plt.ylabel("Stocks priceas y points")
plt.show()

# %%
# Can we make line more thicker?
plt.plot(x, y, color = "blue", marker='o', linestyle="--", linewidth='5', markersize="15")
plt.title("Line chart to understand the syntax")
plt.xlabel("Day interval as x points")
plt.ylabel("Stocks priceas y points")
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y1 = [5, 1, 7, 8, 2]
y2 = [7, 8, 3, 5, 3]

plt.plot(x, y1, color='green', marker='o', linestyle='--', linewidth=3, markersize=6, label="Label of y1 as tata motors")
plt.plot(x, y2, color = "red", marker = "*", markersize=3, linewidth=3, label="label of y2 waree engineering")

plt.title("Multiple lines in one plot")
plt.xlabel("Days")
plt.ylabel("Stock price")

# We have to call the label then only it will display on line
plt.legend()
plt.show()

# %% [markdown]
# ### Plotting Mathmatical plot like sin, cos, tan

# %%
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x), label="sin(x) plot", linestyle = "--")
plt.plot(x, np.cos(x), label="cos(x) plot")
plt.legend()

# %%
plt.plot(x, np.tan(x), linestyle="-.")

# %%
plt.plot(x, (1/np.cos(x)), '.-')

# '.-' >> this is combination of linestyle and marker

# %%
plt.plot(x, np.cos(x), ':')

# %% [markdown]
# ### 2 Seperate plots in one page

# %%
plt.figure() # Initialising a page to make plot

plt.subplot(1, 2, 1) # subplot(nrows, ncols, index, **kwargs)
plt.plot(x, np.sin(x))

plt.subplot(1, 2, 2)
plt.plot(x, np.cos(x))

# It is optional but for best practise use it.
plt.show()

# %%
plt.figure()

plt.subplot(2, 1, 1)
plt.plot(x, np.sin(x))

plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x))

plt.show()

# %%
# 4 Subplots
plt.figure()
plt.subplot(2, 2, 1)
plt.plot(x, np.sin(x))

plt.subplot(2, 2, 2)
plt.plot(x, np.cos(x))

plt.subplot(2, 2, 3)
plt.plot(x, np.tan(x))

plt.subplot(2, 2, 4)
plt.plot(x, 1/np.sin(x))

plt.show()

# %%
plt.plot(x, np.sin(x), color='b')

# %%
plt.plot(x, np.sin(x-0), color='b')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.show()

# %%
# I want the plot to be spread equallu
plt.plot(x, np.sin(x), color='b')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.axis('equal')
plt.show()

# %%
plt.plot(x, np.sin(x), color='b')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.axis('equal')
plt.grid()
plt.show()

# %%
plt.plot(x, np.sin(x))
ax = plt.gca() # get current axis
ax.spines['bottom'].set_position(('data', 0))
ax.spines['left'].set_position(('data', 0))
plt.grid()

# %%
plt.plot(x, np.sin(x), color='b')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.axis('equal')
plt.grid()

plt.title("Graph of sin(x)")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %% [markdown]
# ### Histogram >>
# A **histogram** is a powerful tool for visualizing the distribution of continuous numerical data, helping to uncover patterns, trends, and outliers. By grouping data into bins and representing frequencies with bars, it provides insights into data spread, symmetry, skewness, and variations. Whether identifying peaks, detecting gaps, or comparing datasets, histograms make it easy to analyze and interpret large amounts of information at a glance.
# </br>
# </br>
# **Continuous numerical data** consists of measurable values that can take any number within a range, including decimals. Examples: height, temperature, time, and weight.
# </br>
# </br>
# **Discrete numerical data** consists of countable values that have distinct, separate numbers (no decimals). Examples: number of students in a class, goals scored in a match, or cars in a parking lot.

# %%
data = np.random.randn(1000)
plt.hist(data)
plt.show()
# Histogram will divide data in 10 intervals/bins generally
# In which interval, how many data points are there

# %%
data = np.random.randn(1000)
plt.hist(data, color='b', bins=20)
plt.show()

# %%
# Stacked histogram >> 2 histograms together
data1 = np.random.normal(0, 1, 5000)
data2 = np.random.normal(3, 2, 5000)

# %%
plt.hist([data1, data2], bins = 20, color=['b', 'g'], label=['dist1', 'dist2'])
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("Stacked histogram")
plt.show()

# %% [markdown]
# ### Scatter Plot >>
# A **scatter plot** visually represents the relationship between two numerical variables using individual data points. Each point's position is based on its **x** and **y** values, helping to identify patterns, trends, correlations, and outliers. It is widely used in data analysis to explore how one variable affects another, such as the link between study hours and exam scores.

# %%
# ScatterPlot >>  To understand the relationship between 2 features

x = np.random.rand(50)
y = np.random.rand(50)

plt.scatter(x, y)

# %%
x = np.random.rand(50)
y = np.random.rand(50)

plt.scatter(x, y, c = 'r', marker='*')

# %% [markdown]
# ### Bar Plot >>
# A **bar plot** represents categorical data using rectangular bars, where the height (or length) of each bar corresponds to the value or frequency of a category. It is used to compare different groups, identify trends, and visualize distributions in a clear and simple way. Bar plots can be **vertical** or **horizontal** and are widely used in business, statistics, and data analysis.

# %%
# Bar plot >> To see the distribution of categorical variables
x = ["a", "b", "c", "d"] # Name of students
y = [4, 6, 1, 7] # Present in class in a month

plt.bar(x, y, color='g')
plt.grid()
plt.show()

# %%
# Horizontal Bar plot
x = ["a", "b", "c", "d"] # Name of students
y = [4, 6, 1, 7] # Present in class in a month

plt.barh(x, y, color='g')
plt.grid()
plt.show()

# %% [markdown]
# ### Pie-Chart >>
# A **pie chart** is a circular chart divided into slices, where each slice represents a proportion of a whole. It is used to **visualize percentage-based data** and compare different categories. The size of each slice is proportional to its value, making it easy to see dominant categories at a glance. Pie charts are commonly used in business, surveys, and data analysis to show distributions clearly.

# %%
# Pi-Chart >> to understand the percent distribution of data

langs=["c", "python", "java"]
students = [20, 100, 40]

plt.pie(students, labels=langs, autopct="%1.1f%%")
plt.title("Pi-Chart")
plt.show()

# %%
# what if we want to focus on 1 segment
explode = (0.0, 0.1, 0.1)
langs=["c", "python", "java"]
students = [20, 100, 40]

plt.pie(students, labels=langs, autopct="%1.1f%%", explode=explode)
plt.title("Pi-Chart")
plt.show()

# %%
# To make it more beautiful implement shadow
explode = (0.0, 0.1, 0.1)
langs=["c", "python", "java"]
students = [20, 100, 40]

plt.pie(students, labels=langs, autopct="%1.1f%%", explode=explode, shadow=True)
plt.title("Pi-Chart")
plt.show()

# %% [markdown]
# # 3D Plots

# %%
# 3d plot >> 3 dimension plot
x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)

fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x, y, z, c='r')

# %%
pd.read_csv("Bank_churn.csv")
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df = pd.read_csv("Bank_churn.csv")
plt.scatter(x = df["Age"], y = df["Balance"])

# %%
df.plot.scatter(x = 'Age', y='Balance')
# Out:
# <Axes: xlabel='Age', ylabel='Balance'>

# %%
plt.hist(df['Age'], color='g')
# Out:
# (array([ 611., 2179., 3629., 1871.,  828.,  523.,  208.,  127.,   20.,
#            4.]),
#  array([18. , 25.4, 32.8, 40.2, 47.6, 55. , 62.4, 69.8, 77.2, 84.6, 92. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Box Plot
# A **box plot** (or **box-and-whisker plot**) is a graphical representation of data distribution based on five summary statistics: **minimum, first quartile (Q1), median (Q2), third quartile (Q3), and maximum**. It helps identify **central tendency, variability, outliers, and skewness** in a dataset. Box plots are widely used in statistics and data analysis to compare multiple distributions efficiently.

# %%
# boxplot >> to check the distribution of data and outliers(extreme/abnormal) values
df.boxplot(column='Balance')
# Out:
# <Axes: >

# %% [markdown]
# ### Violin Plot >>
# A **violin plot** is a combination of a **box plot** and a **density plot** that shows the distribution of numerical data. It displays the **median, quartiles, and density estimation**, making it useful for understanding both the spread and shape of the data. Violin plots are especially helpful when comparing multiple datasets, as they reveal patterns, skewness, and multimodal distributions more effectively than box plots.

# %%
plt.violinplot(df.Balance)
# Out:
# {'bodies': [<matplotlib.collections.FillBetweenPolyCollection at 0x2464da3e510>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x2464da53e60>,
#  'cmins': <matplotlib.collections.LineCollection at 0x2464da6d820>,
#  'cbars': <matplotlib.collections.LineCollection at 0x2464dac7c50>}

# %% [markdown]
# ### Area Plot
# An **area plot** is similar to a line plot but with the area beneath the line filled with color. It is used to visualize **trends over time**, showing how values accumulate or change. Area plots are useful for comparing multiple datasets and highlighting the magnitude of differences. They are commonly used in financial data, population growth analysis, and time-series data visualization.

# %%
# Area Plot >> Variables changed over time

years = [2021, 2018, 2022, 2023, 2017]
catg1 = [20, 45, 34, 76, 34]
catg2 = [50, 45, 42, 66, 54]
catg3 = [67, 67, 34, 28, 56]

plt.stackplot(years, catg1, catg2, catg3, labels=["Category 1", "Category 2", "Category 3"], colors=['Magenta', 'black', "lightgreen"])
plt.xlabel("Years")
plt.xlabel("Product selled")
plt.title("Area Plot")
plt.legend()
plt.show()

# %% [markdown]
# ### **How to Decide Which Type of Plot to Use**
#
# - **Comparison:**
#   - **Bar Plot** → Compare categorical data
#   - **Line Plot** → Show trends over time
#
# - **Distribution:**
#   - **Histogram** → Visualize the frequency of numerical data
#   - **Box Plot** → Show summary statistics and outliers
#   - **Violin Plot** → Display data distribution with density
#
# - **Relationship:**
#   - **Scatter Plot** → Show correlation between two numerical variables
#   - **Relplot** → Analyze relationships flexibly
#
# - **Composition:**
#   - **Pie Chart** → Represent proportions of a whole
#   - **Stacked Area Plot** → Show how values change over time
#
# Choosing the right plot depends on **data type** (numerical/categorical) and **analysis goal** (trend, comparison, correlation, distribution, etc.). 🚀
